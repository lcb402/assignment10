# %%
import pandas as pd
import numpy as np

# %%
# Load data
data = pd.read_csv('DOHMH_New_York_City_Restaurant_Inspection_Results.csv',sep=',',header=0)

# %%
# Clean data
data = data.dropna(subset = ['GRADE'])
data = data[~data['GRADE'].str.contains('Not Yet Graded')]
data = data[~data['GRADE'].str.contains('P')]
data = data[~data['GRADE'].str.contains('Z')]
data_si = data['BORO']=='STATEN ISLAND'
data_bx = data['BORO']=='BRONX'
data_bk = data['BORO']=='BROOKLYN'
data_qu = data['BORO']=='QUEENS'
data_ny = data['BORO']=='MANHATTAN'
# Out:
#            CAMIS                             DBA       BORO    BUILDING  \
# 0       30075445           MORRIS PARK BAKE SHOP      BRONX        1007
# 1       30075445           MORRIS PARK BAKE SHOP      BRONX        1007
# 3       30075445           MORRIS PARK BAKE SHOP      BRONX        1007
# 4       30075445           MORRIS PARK BAKE SHOP      BRONX        1007
# 12      30075445           MORRIS PARK BAKE SHOP      BRONX        1007
# 13      30075445           MORRIS PARK BAKE SHOP      BRONX        1007
# 22      30112340                         WENDY'S   BROOKLYN  469
# 23      30112340                         WENDY'S   BROOKLYN  469
# 24      30112340                         WENDY'S   BROOKLYN  469
# 25      30112340                         WENDY'S   BROOKLYN  469
# 29      30112340                         WENDY'S   BROOKLYN  469
# 30      30112340                         WENDY'S   BROOKLYN  469
# 31      30112340                         WENDY'S   BROOKLYN  469
# ...

# %%
data_si

# %%
# Improving? 
restaurants = data['CAMIS'].unique()

def test_grades(restaurant):
    grades = ['A','B','C']
    rest_data = data[data['CAMIS'] == restaurant]
    rest_data['GRADE DATE'] = pd.to_datetime(rest_data['GRADE DATE'])
    rest_data = rest_data.sort(['GRADE DATE'])
    rest_data = rest_data.reset_index()
    first_grade = rest_data.iloc[0]['GRADE']
    last_grade = rest_data.iloc[-1]['GRADE']
    grade1 = grades.index(first_grade)
    grade2 = grades.index(last_grade)
    if grade1 == grade2:
        improve = 0
    elif grade1 < grade2:
        improve = 1
    elif grade1 > grade2:
        improve = -1
    return improve

# %%
improve_list = []

for r in restaurants:
    improve_list.append(test_grades(r))
    
print improve_list

# %%
print improve_list.count(-1)
print improve_list.count(1)
print improve_list.count(0)
